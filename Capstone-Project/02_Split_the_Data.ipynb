# %% [markdown]
# # 02 Split the data into training and test set

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
# %matplotlib inline
from datetime import datetime
import seaborn as sns
from pandas import Grouper
from missingpy import MissForest

from pandas.plotting import register_matplotlib_converters
from missingpy import MissForest

# %% [markdown]
# I read the data I have cleaned and slightly preprocessed in the EDA.

# %%
data = pd.read_pickle('tidy_dataframe_capstone.csv')

# %%
data.shape
# Out:
# (35048, 28)

# %%
data.head()
# Out:
#                     Weekday  Season  Year  Month Day  Hour  SO2   NO2     CO  \
# Date and Time
# 2013-03-01 16:00:00  Friday  winter  2013      3   1    16  7.0   9.0  300.0
# 2013-03-01 17:00:00  Friday  winter  2013      3   1    17  8.0  14.0  300.0
# 2013-03-01 18:00:00  Friday  winter  2013      3   1    18  9.0  20.0  400.0
# 2013-03-01 19:00:00  Friday  winter  2013      3   1    19  7.0  29.0  500.0
# 2013-03-01 20:00:00  Friday  winter  2013      3   1    20  6.0  29.0  500.0
#
#                        O3  ...  it_rained  Lag-1  Lag-2  Lag-3 Lag-4  Lag-5  \
# Date and Time              ...
# 2013-03-01 16:00:00  72.0  ...          0   12.0    3.0    3.0   3.0    3.0
# 2013-03-01 17:00:00  67.0  ...          0   11.0   12.0    3.0   3.0    3.0
# 2013-03-01 18:00:00  58.0  ...          0   13.0   11.0   12.0   3.0    3.0
# 2013-03-01 19:00:00  50.0  ...          0   10.0   13.0   11.0  12.0    3.0
# 2013-03-01 20:00:00  47.0  ...          0   10.0   10.0   13.0  11.0   12.0
#
#                      Lag-6  Lag-7  Lag-8       EMA
# Date and Time
# 2013-03-01 16:00:00    3.0    3.0    3.0  4.925471
# 2013-03-01 17:00:00    3.0    3.0    3.0  5.753260
# 2013-03-01 18:00:00    3.0    3.0    3.0  6.150140
# 2013-03-01 19:00:00    3.0    3.0    3.0  6.480855
# 2013-03-01 20:00:00    3.0    3.0    3.0  6.840187
#
# [5 rows x 28 columns]

# %%
data.tail()
# Out:
#                      Weekday  Season  Year  Month Day  Hour  SO2   NO2     CO  \
# Date and Time
# 2017-02-28 19:00:00  Tuesday  winter  2017      2  28    19  3.0  24.0  400.0
# 2017-02-28 20:00:00  Tuesday  winter  2017      2  28    20  3.0  41.0  500.0
# 2017-02-28 21:00:00  Tuesday  winter  2017      2  28    21  4.0  38.0  500.0
# 2017-02-28 22:00:00  Tuesday  winter  2017      2  28    22  4.0  30.0  400.0
# 2017-02-28 23:00:00  Tuesday  winter  2017      2  28    23  4.0  38.0  600.0
#
#                        O3  ...  it_rained  Lag-1  Lag-2  Lag-3 Lag-4  Lag-5  \
# Date and Time              ...
# 2017-02-28 19:00:00  72.0  ...          0   11.0   11.0    6.0  11.0    3.0
# 2017-02-28 20:00:00  50.0  ...          0   11.0   11.0   11.0   6.0   11.0
# 2017-02-28 21:00:00  54.0  ...          0   13.0   11.0   11.0  11.0    6.0
# 2017-02-28 22:00:00  59.0  ...          0   14.0   13.0   11.0  11.0   11.0
# 2017-02-28 23:00:00  49.0  ...          0   12.0   14.0   13.0  11.0   11.0
#
#                      Lag-6  Lag-7  Lag-8        EMA
# Date and Time
# 2017-02-28 19:00:00    3.0    6.0    4.0  57.043537
# 2017-02-28 20:00:00    3.0    3.0    6.0  56.799528
# 2017-02-28 21:00:00   11.0    3.0    3.0  56.562412
# 2017-02-28 22:00:00    6.0   11.0    3.0  56.315528
# 2017-02-28 23:00:00   11.0    6.0   11.0  56.075553
#
# [5 rows x 28 columns]

# %% [markdown]
# ## Split the data into train and test data

# %% [markdown]
# I will split the dataset into train, and test sets. Since the time series data cannot be shufled and the order has to be maintained, I need to make sure that the test set covers a later period in time from the training set, to prevent any information about the future from "leaking" into the model during training. I decide to use the lasst six months of the data (i.e. the last month of the data set) for the test set.

# %%
# Define a function to split the data into training and test sets

def train_test_split(df, start_dt):
    
    '''
    This function performs train/test splitting for time-series data.
    
    Arguments
    ---------
    - df        : the data (features & target)
    - start_df  : the starting date for the test set
    
    Outputs
    -------
    - X_tr,y_tr : X/y arrays for train set
    - X_te,y_te : X/y arrays for test data
    '''

    # Train set
    X_tr = df[df.index < test_start_dt].drop('PM2.5',axis=1).values
    y_tr = df[df.index < test_start_dt]['PM2.5']

    # Test set
    X_te = df[df.index >= test_start_dt].drop('PM2.5',axis=1).values
    y_te = df[df.index >= test_start_dt]['PM2.5']
    
    print('Train set')
    print('---------')
    print('Features: {} Target: {}\n'.format(X_tr.shape,y_tr.shape))

    print('Test set')
    print('--------')    
    print('Features: {} Target: {}'.format(X_te.shape,y_te.shape))
    
    return (X_tr,X_te,y_tr,y_te)

# %%
test_start_dt = '2016-09-01'
X_tr, X_te, y_tr, y_te = train_test_split(data, test_start_dt)
# Out:
# Train set
# ---------
# Features: (30704, 27) Target: (30704,)
#
# Test set
# --------
# Features: (4344, 27) Target: (4344,)

# %%
pd.to_datetime('02-01-2013')
# Out:
# Timestamp('2013-02-01 00:00:00')

# %%
pd.to_datetime('01-03-2013')
# Out:
# Timestamp('2013-01-03 00:00:00')

# %%
pd.to_datetime('01-20-2013')
# Out:
# Timestamp('2013-01-20 00:00:00')

# %%
pd.to_datetime('01-04-2013')
# Out:
# Timestamp('2013-01-04 00:00:00')

# %%
pd.to_datetime('2016-09-01')
# Out:
# Timestamp('2016-09-01 00:00:00')

# %% [markdown]
# I am checking the last observation of the training set.

# %%
X_tr[30703]
# Out:
# array(['Wednesday', 'summer', 2016, 8, 31, 23, 2.0, 33.0, 200.0, 48.0,
#        27.7, 991.2, -2.2, 0.0, 'NW', 1.1, 49.0, 0, 6.0, 13.0, 12.0, 12.0,
#        11.0, 8.0, 4.0, 11.0, 35.67288448364514], dtype=object)

# %% [markdown]
# data_tr is the dataframe that corresponds to the training set.

# %%
data_tr = data[:'2016-08-31 23:00:00']

# %%
data_te = data['2016-09-01 00:00:00':]

# %%
data_tr.head(3)
# Out:
#                     Weekday  Season  Year  Month Day  Hour  SO2   NO2     CO  \
# Date and Time
# 2013-03-01 16:00:00  Friday  winter  2013      3   1    16  7.0   9.0  300.0
# 2013-03-01 17:00:00  Friday  winter  2013      3   1    17  8.0  14.0  300.0
# 2013-03-01 18:00:00  Friday  winter  2013      3   1    18  9.0  20.0  400.0
#
#                        O3  ...  it_rained  Lag-1  Lag-2  Lag-3 Lag-4  Lag-5  \
# Date and Time              ...
# 2013-03-01 16:00:00  72.0  ...          0   12.0    3.0    3.0   3.0    3.0
# 2013-03-01 17:00:00  67.0  ...          0   11.0   12.0    3.0   3.0    3.0
# 2013-03-01 18:00:00  58.0  ...          0   13.0   11.0   12.0   3.0    3.0
#
#                      Lag-6  Lag-7  Lag-8       EMA
# Date and Time
# 2013-03-01 16:00:00    3.0    3.0    3.0  4.925471
# 2013-03-01 17:00:00    3.0    3.0    3.0  5.753260
# 2013-03-01 18:00:00    3.0    3.0    3.0  6.150140
#
# [3 rows x 28 columns]

# %%
data_tr.tail(3)
# Out:
#                        Weekday  Season  Year  Month Day  Hour  SO2   NO2  \
# Date and Time
# 2016-08-31 21:00:00  Wednesday  summer  2016      8  31    21  2.0  22.0
# 2016-08-31 22:00:00  Wednesday  summer  2016      8  31    22  2.0  24.0
# 2016-08-31 23:00:00  Wednesday  summer  2016      8  31    23  2.0  33.0
#
#                         CO    O3  ...  it_rained  Lag-1  Lag-2  Lag-3 Lag-4  \
# Date and Time                     ...
# 2016-08-31 21:00:00  200.0  68.0  ...          0   12.0   12.0   11.0   8.0
# 2016-08-31 22:00:00  200.0  63.0  ...          0   13.0   12.0   12.0  11.0
# 2016-08-31 23:00:00  200.0  48.0  ...          0    6.0   13.0   12.0  12.0
#
#                      Lag-5  Lag-6  Lag-7  Lag-8        EMA
# Date and Time
# 2016-08-31 21:00:00    4.0   11.0   11.0   19.0  36.004423
# 2016-08-31 22:00:00    8.0    4.0   11.0   11.0  35.838193
# 2016-08-31 23:00:00   11.0    8.0    4.0   11.0  35.672884
#
# [3 rows x 28 columns]

# %%
data_te.head(3)
# Out:
#                       Weekday  Season  Year  Month Day  Hour  SO2   NO2  \
# Date and Time
# 2016-09-01 00:00:00  Thursday  summer  2016      9   1     0  2.0  36.0
# 2016-09-01 01:00:00  Thursday  summer  2016      9   1     1  2.0  36.0
# 2016-09-01 02:00:00  Thursday  summer  2016      9   1     2  2.0  33.0
#
#                         CO    O3  ...  it_rained  Lag-1  Lag-2  Lag-3 Lag-4  \
# Date and Time                     ...
# 2016-09-01 00:00:00  300.0  36.0  ...          0    6.0    6.0   13.0  12.0
# 2016-09-01 01:00:00  300.0  28.0  ...          0   12.0    6.0    6.0  13.0
# 2016-09-01 02:00:00  300.0  28.0  ...          0   17.0   12.0    6.0   6.0
#
#                      Lag-5  Lag-6  Lag-7  Lag-8        EMA
# Date and Time
# 2016-09-01 00:00:00   12.0   11.0    8.0    4.0  35.541733
# 2016-09-01 01:00:00   12.0   12.0   11.0    8.0  35.439008
# 2016-09-01 02:00:00   13.0   12.0   12.0   11.0  35.259291
#
# [3 rows x 28 columns]

# %%
data_te.tail(3)
# Out:
#                      Weekday  Season  Year  Month Day  Hour  SO2   NO2     CO  \
# Date and Time
# 2017-02-28 21:00:00  Tuesday  winter  2017      2  28    21  4.0  38.0  500.0
# 2017-02-28 22:00:00  Tuesday  winter  2017      2  28    22  4.0  30.0  400.0
# 2017-02-28 23:00:00  Tuesday  winter  2017      2  28    23  4.0  38.0  600.0
#
#                        O3  ...  it_rained  Lag-1  Lag-2  Lag-3 Lag-4  Lag-5  \
# Date and Time              ...
# 2017-02-28 21:00:00  54.0  ...          0   13.0   11.0   11.0  11.0    6.0
# 2017-02-28 22:00:00  59.0  ...          0   14.0   13.0   11.0  11.0   11.0
# 2017-02-28 23:00:00  49.0  ...          0   12.0   14.0   13.0  11.0   11.0
#
#                      Lag-6  Lag-7  Lag-8        EMA
# Date and Time
# 2017-02-28 21:00:00   11.0    3.0    3.0  56.562412
# 2017-02-28 22:00:00    6.0   11.0    3.0  56.315528
# 2017-02-28 23:00:00   11.0    6.0   11.0  56.075553
#
# [3 rows x 28 columns]

# %%
data_tr.shape
# Out:
# (30704, 28)

# %%
data_te.shape
# Out:
# (4344, 28)

# %%
X_tr.shape
# Out:
# (30704, 27)

# %%
X_te.shape
# Out:
# (4344, 27)

# %% [markdown]
# checking the last entry of the training set.

# %%
X_tr[30711:30712]
# Out:
# array([], shape=(0, 27), dtype=object)

# %%
X_tr
# Out:
# array([['Friday', 'winter', 2013, ..., 3.0, 3.0, 4.925471414010265],
#        ['Friday', 'winter', 2013, ..., 3.0, 3.0, 5.753259698051195],
#        ['Friday', 'winter', 2013, ..., 3.0, 3.0, 6.150140202624346],
#        ...,
#        ['Wednesday', 'summer', 2016, ..., 11.0, 19.0, 36.00442251994568],
#        ['Wednesday', 'summer', 2016, ..., 11.0, 11.0, 35.838193032300545],
#        ['Wednesday', 'summer', 2016, ..., 4.0, 11.0, 35.67288448364514]],
#       dtype=object)

# %% [markdown]
# I now need to drop the target variable to have the same columns for the x_tr dataframe.

# %%
data_tr.columns
# Out:
# Index(['Weekday', 'Season', 'Year', 'Month', 'Day', 'Hour', 'SO2', 'NO2', 'CO',
#        'O3', 'TEMP', 'PRES', 'DEWP', 'RAIN', 'wd', 'WSPM', 'PM10', 'PM2.5',
#        'it_rained', 'Lag-1', 'Lag-2', 'Lag-3', 'Lag-4', 'Lag-5', 'Lag-6',
#        'Lag-7', 'Lag-8', 'EMA'],
#       dtype='object')

# %%
data_te.columns
# Out:
# Index(['Weekday', 'Season', 'Year', 'Month', 'Day', 'Hour', 'SO2', 'NO2', 'CO',
#        'O3', 'TEMP', 'PRES', 'DEWP', 'RAIN', 'wd', 'WSPM', 'PM10', 'PM2.5',
#        'it_rained', 'Lag-1', 'Lag-2', 'Lag-3', 'Lag-4', 'Lag-5', 'Lag-6',
#        'Lag-7', 'Lag-8', 'EMA'],
#       dtype='object')

# %% [markdown]
# I save the data_tr and data_te because they will be used for the missing value imputation of 'wd'.

# %%
data_tr.to_pickle('training_dataset_df.csv')
# df = pd.read_pickle(file_name)

# %%
data_te.to_pickle('test_dataset_df.csv')

# %% [markdown]
# I save the target for training and testing subset.

# %%
np.save('y_tr', y_tr)
np.save('y_te', y_te)

# %%
y_tr.to_pickle('y_tr.csv')
y_te.to_pickle('y_te.csv')

# %%
pd.DataFrame(y_te)
# Out:
#                      PM2.5
# Date and Time
# 2016-09-01 00:00:00   12.0
# 2016-09-01 01:00:00   17.0
# 2016-09-01 02:00:00    3.0
# 2016-09-01 03:00:00    8.0
# 2016-09-01 04:00:00   14.0
# 2016-09-01 05:00:00   13.0
# 2016-09-01 06:00:00    7.0
# 2016-09-01 07:00:00    8.0
# 2016-09-01 08:00:00   10.0
# 2016-09-01 09:00:00    3.0
# 2016-09-01 10:00:00    7.0
# 2016-09-01 11:00:00    3.0
# 2016-09-01 12:00:00    4.0
# 2016-09-01 13:00:00    4.0
# 2016-09-01 14:00:00    6.0
# 2016-09-01 15:00:00    5.0
# 2016-09-01 16:00:00    9.0
# 2016-09-01 17:00:00    6.0
# 2016-09-01 18:00:00   10.0
# 2016-09-01 19:00:00   10.0
# 2016-09-01 20:00:00   18.0
# 2016-09-01 21:00:00    9.0
# 2016-09-01 22:00:00    9.0
# 2016-09-01 23:00:00   19.0
# 2016-09-02 00:00:00   28.0
# 2016-09-02 01:00:00   24.0
# 2016-09-02 02:00:00   19.0
# 2016-09-02 03:00:00   19.0
# 2016-09-02 04:00:00   23.0
# 2016-09-02 05:00:00   18.0
# ...                    ...
# 2017-02-27 18:00:00   46.0
# 2017-02-27 19:00:00   51.0
# 2017-02-27 20:00:00   48.0
# 2017-02-27 21:00:00   57.0
# 2017-02-27 22:00:00   54.0
# 2017-02-27 23:00:00   52.0
# 2017-02-28 00:00:00   40.0
# 2017-02-28 01:00:00   20.0
# 2017-02-28 02:00:00   10.0
# 2017-02-28 03:00:00   11.0
# 2017-02-28 04:00:00   10.0
# 2017-02-28 05:00:00   11.0
# 2017-02-28 06:00:00   11.0
# 2017-02-28 07:00:00   10.0
# 2017-02-28 08:00:00    3.0
# 2017-02-28 09:00:00    9.0
# 2017-02-28 10:00:00   10.0
# 2017-02-28 11:00:00    4.0
# 2017-02-28 12:00:00    6.0
# 2017-02-28 13:00:00    3.0
# 2017-02-28 14:00:00    3.0
# 2017-02-28 15:00:00   11.0
# 2017-02-28 16:00:00    6.0
# 2017-02-28 17:00:00   11.0
# 2017-02-28 18:00:00   11.0
# 2017-02-28 19:00:00   11.0
# 2017-02-28 20:00:00   13.0
# 2017-02-28 21:00:00   14.0
# 2017-02-28 22:00:00   12.0
# 2017-02-28 23:00:00   13.0
#
# [4344 rows x 1 columns]
